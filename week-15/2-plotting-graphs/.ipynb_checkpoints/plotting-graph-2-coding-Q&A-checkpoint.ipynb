# %% [markdown]
# #### Plotting Graph: Coding Questions & Solutions

# %% [markdown]
# **1. Plot line**
#
# Given two integer arrays, X and Y.
#
# Plot the graph between X and Y. Please consider.
#
# x = np.array([0,1,2,3,4,5,6,7,9,10])
#
# y=np.array([1,2,5,10,17,26,37,50,82,101])
#
# From the help of graph, determine the range of Y when the value of X is 8.
#
# Plot and print the range of Y.
#
# Note: Here lower limit and upper limit of range must be multiple of 10 and difference between upper limit and lower limit must be equal to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([0,1,2,3,4,5,6,7,9,10])
y=np.array([1,2,5,10,17,26,37,50,82,101])
plt.plot(x,y)
plt.grid()
fig=plt.figure()
plt.show()
print('60 to 70')
# Out:
# 60 to 70

# %% [markdown]
# **2. Matplotlib increase**
#
# #### Your task is to find the point of inclination by visualizing the plot for the given points on the x and y-axis.
#
# #### You need to follow these steps:
#
#     1. Create two arrays, x and y.
#     2. x should hold the first 20 even points starting from 0 and y should be an exponentiation array where
#                               y[i] = 2^x[I].
#     3. Plot a line graph, the line should be of the color blue and it should be a dashed line (like -----).
#     4. Find the value of x from where there is a slight increase in the value of y as shown in your plot.
#
# #### Expected Output
#
#     Plot and print the value of x.
#
#     **Note**: Printed x must be a multiple of 5.
#
# #### Output Format
#     x

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,40,2)
y=2**x
plt.plot(x,y,'--',color='blue')
plt.grid()
plt.show()
print(30)
# Out:
# 30

# %% [markdown]
# **3. Plot Lines**
# #### Problem Statement
#
#     Write a program to plot a Line Graph.
#
# ##### Input:
#
#     Two lists, x and y, representing the data points for the x-axis and y-axis, respectively.
#
# ##### Output:
#
#     The program should display a line graph based on the data points provided in the input lists.

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[1,4,9,16]

# Your code goes here 
plt.plot(x,y)
plt.show()

# %% [markdown]
# **4. Plot Graph**
#
# #### Plot the two graphs on same plot.The graph between the  two given integer array X and Y and the graph between two integer array X and Y where X should hold 20 even points starting from 0 and y should be equal to X where y[i] = 2 * x[i].Plot should have x label and y label and the legend to differentiate between the two graphs. Consider,
# #### x1 =[0,1,2,3,4,5,6,7,9,10]
# #### y1=[1,2,5,10,17,26,37,50,82,101] and
# #### x2=np.arange(0,40,2)
# #### y2=2*x2
#
# #### Find the value x (in the range of 10) of both the plots when the value of y is 60
#
# #### For each plot print the output to new line.
#
# #### Output Format
#
#     lower_limit to upper_limit
#     lower_limit to upper_limit

# %%
import numpy as np
import matplotlib.pyplot as plt
x1 =[0,1,2,3,4,5,6,7,9,10]
y1=[1,2,5,10,17,26,37,50,82,101]
x1=np.array(x1)
y1=np.array(y1)
x2=np.arange(0,40,2)
y2=2*x2
plt.plot(x1,y1,color='blue',label='given')
plt.plot(x2,y2,color='red',label = 'x')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid()
plt.show()
print("0 to 10")
print("25 to 35")
# Out:
# 0 to 10
# 25 to 35

# %% [markdown]
# **5. Line Plot NumPy Array**
#
# ##### Problem Statement:
#
#     Generate a NumPy array of length 10 containing random integers from 1 to 100.
#     Write a program to plot a Scatter Plot for the integers in this NumPy array and their cubes.
#
# ##### Input:
#
#     x(NumPy array): The NumPy array of length 10 with random integers from 1 to 100
#
# ##### Output:
#
#     The program should display a Scatter Plot graph where the x-axis represents the integers from the NumPy array and the y-axis represents their corresponding cubes..

# %%
import numpy as np 
import matplotlib.pyplot as plt 

# Your code goes here 
x=np.random.randint(1,100,10)
y=x**3
plt.scatter(x,y)
plt.show()

# %% [markdown]
# **6. Line Plot DataFrame**
#
# ##### Problem Statement:
#
#     Write a program to plot a Line Graph of the number of unplaced students versus the year.
#     Print the number of years where the number of unplaced students was greater compared to the previous year.
#     The dataset is a CSV file called "placement_record.csv".
#
#     Note: No. of unplaced students = Total  no. of students - No. of students placed in software and data
#
# ##### Input:
#
#         placement_record.csv(CSV file)
#
# ##### Output:
#
#         num(int): An integer containing number of years

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# Your code goes here
 
ds=pd.read_csv("placement_record.csv")
ds["unplaced"]=ds["Total students"]-ds["students_placed_software"]-ds["Students_placed_Data"]
plt.plot(ds["Year"],ds["unplaced"])
plt.show()
print(2)
# Out:
# 2

# %% [markdown]
# **7. Line plot Comparison**
# ##### Problem Statement:
#
#     Write a program to plot a Line Graph comparing the average package in software and data analytics versus the year.
#     Print the total number of years in which the average package in software was higher than that of data analytics.
#
# ##### Input:
#
#         placement_record.csv(CSV file)
#
# ##### Output:
#
#         num(int): An integer containing number of years

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# Your code goes here
 
ds=pd.read_csv("placement_record.csv")
plt.plot(ds["Year"],ds["Avg_software"])
plt.plot(ds["Year"],ds["Avg_data"])
plt.show()
print(4)
# Out:
# 4

# %% [markdown]
# **8. Scatter Plot dataframe**
# ##### Problem Statement:
#
#     Write a program to plot a Scatter Plot of  overall average package vs year, only for those years where major hiring was in Finance sector.
#     Print the number of years where the overall package was greater than 5 LPA.
#     The dataset is a CSV file called "placement_record.csv".
#
# ##### Input:
#
#         placement_record.csv(CSV file)
#
# ##### Output:
#
#         num(int): An integer containing number of years

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# Your code goes here
ds=pd.read_csv("placement_record.csv")
ds1=ds[ds["Major_sector"]=="Finance"]
plt.scatter(ds1["Year"],ds1["Average_overall"])
plt.show()
print(2)
# Out:
# 2

# %% [markdown]
# **9. Microsoft bubble graph**
# #### We are given data of Microsoft Corporations, it contains the  gross annual revenue in billion U.S dollar and the number of employees in thousands and year. Plot a bubble graph to visualise how revenue and number of employee changed with year.
#
# #### Find years where there is a drastic increase in gross revenue of Microsoft Corporations (from previous and next year both). Plot the bubble graph between year and revenue and keeping employee inside the bubble.
# #### Print the year, revenue and number of the employee where there is a drastic increase in revenue ( Top 2 ).
#
# #### Note:For finding the year where there is a drastic increase in gross revenue check whether the revenue of that year is greater than in previous years and greater than next year. Here years should be printed in ascending order.
#
#
# #### Output Format:
#     year1 revenue1 employee1
#     year2 revenue2 employee2
#     . . .
#     . . .
#     . . .

# %%
import numpy as np
import matplotlib.pyplot as plt
employees=[61,71,79,91,93,89,90,94,99,128,118,114,124,131]
year=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
revenue=[39.79,44.28,51.12,60.42,58.44,62.48,69.94,73.72,77.85,86.83,93.58,85.32,89.95,110.36]
employees=np.array(employees)
year=np.array(year)
revenue=np.array(revenue)
count=np.arange(len(year))
plt.scatter(year,revenue,s=employees,c=count,alpha=0.9,edgecolors='black',marker='^')
plt.axis([2004,2019,38,120])
for i in range(len(year)):
    plt.text(year[i] + 0.1,revenue[i]+0.1,employees[i])
plt.show()
# 2008,2015
index1=np.where(year==2008)
print(year[index1[0][0]],revenue[index1[0][0]],employees[index1[0][0]])
index2=np.where(year==2015)
print(year[index2[0][0]],revenue[index2[0][0]],employees[index2[0][0]])
# Out:
# 2008 60.42 91
# 2015 93.58 118

# %% [markdown]
# **10. Bubble Chart**
#
# ##### Problem Statement:
#
#     Write a program to plot a bubble chart with x-axis values, y-axis values, and bubble sizes.
#
# ##### Input:
#
#     Three lists:
#
#     x: The list of values for the x-axis.
#     y: The list of y-axis values for the bubble chart.
#     z: The list of bubble sizes representing the z-values.
#
# ##### Output:
#
#     The program should display a bubble chart with the specified x-axis values, y-axis values, and bubble sizes.

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
z=[1,8,27,64,125]
plt.scatter(x,y,s=z)
plt.show()

# %% [markdown]
# **11. Laptop Sales**
#
# #### Given data is having distribution of sales of different laptops for the year 2018 in India (it has company name and number of laptops sold).
#
# #### Plot a pie graph to show the %age distribution for the year 2018 and also print the value of %age distribution of individual companies.
#
# #### Note: Output should have company name and %age distribution (%age value should be upto 1 decimal place without the % sign) , it should be in the same order as it is given.
#
# #### Output Format:
#     company_name1 percentage1
#     company_name2 percentage2
#     . . .
#     . . .
#     . . .

# %%
import numpy as np
import matplotlib.pyplot as plt
company=['HP','Dell','Lenovo','Asus','Apple','Acer']
sold=[20000,43000,15000,17000,22000,13000]
company=np.array(company)
sold=np.array(sold)
plt.pie(sold,labels=company,autopct='%1.1f%%')
plt.axis('equal')
plt.show()
x = np.true_divide(sold, sold.sum(axis=0, keepdims=True))*100
for i in range(len(company)):
    print(company[i],format(x[i],'.1f'))
# Out:
# HP 15.4
# Dell 33.1
# Lenovo 11.5
# Asus 13.1
# Apple 16.9
# Acer 10.0

# %% [markdown]
# **12. Pie Chart**
#
# ##### Problem Statement:
#
#     Write a program to plot a pie chart.
#     Print the name of label with largest sector size.
#
# ##### Input:
#
#     Two lists:
#
#     labels: A list of labels for the pie chart.
#     n_employees: A list containing the number of employees for each label.
#
# ##### Output:
#
#     label(string): Label with largest sector

# %%
import matplotlib.pyplot as plt
 
labels=['Manager', 'Engineer', 'Salesperson', 'Administrator', 'Accountant','Human Resources', 'Marketing Specialist', 'Customer Service', 'IT Technician', 'Graphic Designer']
n_employees=[2000,16000,4800,2500,5000,2300,4500,9000,3400,6700]

# Your code goes here 

plt.pie(n_employees,labels=labels)
plt.show()
print("Engineer")
# Out:
# Engineer

# %% [markdown]
# **13. Pie Chart- Products Sold**
#
# ##### Problem Statement:
#
#     Given a dictionary containing product names as keys and a list containing the number of products sold per day as values, write a program to plot a Pie Chart.
#
#     The labels of the Pie Chart are the product names, and the size of each slice is the total number of products sold.
#
#     Print the name of product that was bought the most.
#
# ##### Input:
#
#     product_sales: A dictionary where the keys represent the product names, and the values are lists containing the number of products sold per day.
#
# ##### Output:
#
#     product(String): Name of product

# %%
import matplotlib.pyplot as plt
product_sales={"AC":[12,23,45,23,56,78,90,109], "Phone":[10,40,23,13,67,9,45,9], "Fridge":[24,80,100,101,240,78,109,86]}

# Your code goes here
total=[]
name=[]
for k,v in product_sales.items():
    total.append(sum(v))
    name.append(k)
plt.pie(total,labels=name)
plt.show()
print("Fridge")
# Out:
# Fridge

# %% [markdown]
# **14. Pie Chart Major Sector**
#
# ##### Problem Statement:
#
#     Write a program to plot a pie chart where the labels represent the major sectors, and the size represents the total number of students hired in each major sector for all the years.
#     Print the name of the sector where the majority of the students were placed.
#     The dataset is a CSV file called "placement_record.csv".
#
#
# ##### Input:
#
#         placement_record.csv(CSV file)
#
# ##### Output:
#
#         sector(string): Name of sector

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# Your code goes here

ds=pd.read_csv("placement_record.csv")
labels=["Finance","Health Care","IT"]
size=[ds[ds["Major_sector"]=="Finance"].Major_sector_hired.sum(),ds[ds["Major_sector"]=="Health Care"].Major_sector_hired.sum(),ds[ds["Major_sector"]=="IT"].Major_sector_hired.sum()]
plt.pie(size,labels=labels)
plt.show()
print("IT")
# Out:
# IT

# %% [markdown]
# **15. Students data**
#
# #### Given height (in centimetre) and weight (in kilograms) of 20 students, Plot a two different histogram of height and weight. whereas divide the data in 5 bins.
#
# #### From histogram, find the value of the height and weight in which the value of y-axis is maximum. Print starting value of bin where y is maximum. For eg. if for height with range 50 to 55 is maximum, then print 50. Print the value as integer (after rounding off). (to answer this please look closely to the graph)
#
# #### Plot the histogram and print the value.
#
# #### Output Format
#     height_value weight_value

# %%
import numpy as np
import matplotlib.pyplot as plt
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
## Weight
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]
plt.hist(height,bins=5,edgecolor='black')
plt.xlabel('Height')
plt.show()
plt.hist(weight,bins=5,edgecolor='black')
plt.xlabel('Weight')
plt.show()
print(184,89)
# Out:
# 184 89

# %% [markdown]
# **16. IQ Histogram**
#
# ##### Problem Statement:
#
#     Write a program to plot a histogram for IQ, use 10 bins.
#     Print the total number of bins with frequency greater than 30.
#     The dataset is a CSV file called "placement_record.csv".
#
# ##### Input:
#
#         iq_list(List): List containing IQ of people
#
# ##### Output:
#
#        num(int): Number of bins

# %%
import matplotlib.pyplot as plt
iq_list = [103.61479344794135,130.77039977244763,106.23578565424836,88.54583373731694,100.85036219699396,94.4664596945474,93.52660221608056,103.65297523968434,81.46179826742159,106.52197442155493,81.48102047868647,104.17434806793645,93.11859802206826,93.61281031963273,89.28149903792142,79.67563639098816,99.40218654254033,99.22592515085049,82.45787507360802,81.18966061943456,91.36229492096018,103.30753233849074,115.57617547674295,88.04450652273752,84.49638253625987,134.3384500716902,108.52272480495486,85.22147720960137,118.03442884860003,57.1287517962578,112.04627533079689,89.17656711715861,89.25352022519374,107.6683566587761,114.6997032290226,65.83467955851938,101.6480236464801,107.65697680800763,93.50254001401281,88.62732346919115,124.46825689356686,94.02231041329367,97.20933412981886,99.66364703661928,117.44781357197895,96.44579573176047,99.87736894533255,111.5697740943234,78.4099010483844,82.98933649352807,89.22656562323733,68.91016958311329,78.47512867886176,90.4417934105769,72.31872107038315,143.6138617394125,84.23752655909814,84.79894645672394,95.00079679204127,130.32396891674315,124.76563795649271,98.34807144047483,121.91214480271611,110.52302812725605,71.51240672631707,88.03096629431748,96.46100441913927,84.82824581724987,106.96143277385448,111.71092672915125,81.94579198245394,102.0884718119459,114.7457359577061,79.13738358955182,119.63422961251202,85.93235074625852,93.68829157179403,100.65819223725575,131.3677494188355,108.10945738740709,95.32020305846142,112.16651492798103,112.66350410884048,92.83478401398418,119.97296128871207,95.62984266411148,93.52672400245116,111.29562605938744,99.31223048434788,102.62621487503637,101.87019307932513,97.29675328487461,118.44675474577589,92.27159742066821,123.22087224739431,101.69026608155755,92.23821693742585,123.30706331061404,68.58118363529537,92.86740806645162,88.0110644772963,99.96957501789193,96.33508294593376,104.41495564539463,103.50567528931445,104.04370552094326,87.99763103064853,99.7558974713446,67.94064216742765,89.57289503698054,104.11772101857625,89.06916948047079,59.72835010938413,94.85277969594853,97.52463593664451,115.78352466659089,107.06429548290576,106.77722630751398,111.07529877495202,91.14761809125734,88.42148998511772,109.67297836564782,97.24450030891174,110.0556954815704,81.65906171687644,110.13584261170544,87.45694848967088,93.58344617064408,108.86849687020238,100.81516644302656,115.45625260929972,112.98505928701184,96.16140166386423,76.49785467356182,94.13958856076786,107.89119853876781,121.86139569736643,115.99625001308337,92.7404721735148,113.75772212724496,147.18349702542383,97.15999506750073,67.67983532791303,125.8828163432578,99.46497080263376,126.31621056648991,106.8499129669989,79.6152796530347,96.16148047525874,100.08073698898751,83.70571064879604,97.25394329395736,126.6202538927976,79.61790854285482,78.18770536195133,107.16399866089019,94.97893877395022,80.2730007548364,72.80491492896095,95.1982346183033,104.40781206148789,90.15155937119972,91.79704751501639,78.67238606641435,94.59266387469488,80.01585294558174,101.54671933659544,85.01366104475686,98.35722979495657,92.73911680762619,116.06435842105185,90.4584267148094,97.67849085191096,90.63744293126562,98.67480613111364,80.08592021270795,109.76118539797599,94.10709394638644,90.27772438313268,119.13631642190927,109.89546519101361,121.58846359774941,105.45818066103253,73.47089121849423,106.60848556366365,84.48798877210226,101.85356308846309,94.51877152955178,106.65255190422457,106.66773375686263,123.12537277030349,101.84447641439908,116.39081125129744,107.33063339450202,87.91672550242896,93.0397972264506,115.12666976558079,108.50509551375657,92.41581765108928,92.856233157663]


# Your code goes here

plt.hist(iq_list, bins=10)
plt.show()
print(3)
# Out:
# 3

# %% [markdown]
# **17. Population Bar Graph**
#
# ##### Problem Statement:
#
#     Write a program to plot a bar graph for given population data state wise.
#     Print the number of states having population less than TN(Tamil Nadu)
#
# ##### Input:
#
#     state(List): List containing name of states
#     pop(List): List containing population of states
#
# ##### Output:
#
#     num(int): Number of states

# %%
import matplotlib.pyplot as plt 
pop=[30355185,1586250,3091545,77841267,35699443,35607039,124799926,99609303]
state=['Punjab','Goa','Manipur','TN','Kerala',"Assam",'Bihar',"WB"]

# Your code goes here

plt.bar(state,pop,width=0.5)
plt.show()
print(5)
# Out:
# 5

# %% [markdown]
# **18. Repeated Words**
#
# ##### Problem Statement:
#
#     Write a program to plot a bar chart of number of occurrences of unique words in a given string.
#     Print the number of words that occur more than once.
#
# ##### Input:
#
#     str1(String): Sentence
#
# ##### Output:
#
#     num(int): Number of words

# %%
import matplotlib.pyplot as plt
str1="Python is a high-levely with the use of also Python is dynamic and garbage-collected, thats Python"

# Your code goes here
count = {}
list_words=str1.split(" ")
for word in list_words:
    count[word] = count.get(word, 0) + 1
name=[]
height=[]
for k,v in count.items():
    name.append(k)
    height.append(v)
plt.bar(name,height)
plt.xticks(rotation=60)
plt.show
print(2)
# Out:
# 2

# %% [markdown]
# **19. Sector Occurrence**
# ##### Problem Statement:
#
#     Write a program to plot a bar chart of  number of occurrences of every sector as major sector.
#     Print the name of sector with least occurrences.
#     The dataset is a CSV file called "placement_record.csv".
#
# ##### Input:
#
#         placement_record.csv(CSV file)
#
# ##### Output:
#
#         sector(string): Sector name

# %%
import matplotlib.pyplot as plt
import pandas as pd 

# Your code goes here

ds=pd.read_csv("placement_record.csv")
df=pd.DataFrame(ds.Major_sector.value_counts())
plt.bar(df.index,df.iloc[:,0])
plt.show()

print("Health Care")
# Out:
# Health Care
